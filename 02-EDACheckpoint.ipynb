# %% [markdown]
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# - Ahmon Embaye: Background research, Visualization, Data curation, Experimental investigation
# - Eugene Bertrand: Data curation, Background research, Analysis, Software, Conceptualization
# - George Robin: Conceptualization, Visualization, Methodology, Background research
# - Hemendra Ande: Software, Data curation, Writing – review & editing, Methodology
# - Harvir Ghuman: Project administration, Writing – original draft, Experimental investigation

# %% [markdown]
# ## Research Question
#
# The main question we aim to answer is: To what extent does a PhD provide a statistically significant decrease in AI-driven automation risk, specifically when compared to 10 years of professional experience? And how exactly does this "shielding effect" vary between technical and service sectors? Is it built on a house of cards, or can it be used to gauge job security reliably?
#
# While foundational models like Frey & Osborne (2017) suggested that high-skill, high-education roles were least susceptible to computerisation, more recent evidence from the Brookings Institution (Muro et al., 2019) suggests that better-educated and better-paid workers now face the most exposure to AI. By evaluating these variables through the task-based framework of Acemoglu & Restrepo (2022), this study seeks to determine if a PhD still serves as a reliable shield against automation or if the cognitive nature of high-level degrees now represents a point of vulnerability in the age of Generative AI.
#
# **Dependent Variable:** Automation Probability 2030 / AI Exposure Index
# **Independent Variables:** Education Level (PhD vs. less than PhD), Years of Experience
# **Moderating Variable:** Technical Job Sector, Service Job Sector
# **Control Variables:** Baseline Skill Profiles, Professional Networks/Connections, Existing Industry-Specific Automation Levels

# %% [markdown]
# ## Background and Prior Work
#
# The rapid integration of Generative AI into the global workforce has sparked an intense debate about which demographics are most vulnerable to job displacement. Unlike earlier waves of automation that primarily replaced manual labor, today’s AI systems generate text, code, and images, allowing them to perform cognitive tasks once associated with college-educated professionals. As adoption has accelerated since 2023, students and workers are questioning whether advanced degrees still provide protection or whether years of professional experience now offer a stronger defense. With 2030 projections approaching, it is no longer clear that a Master’s degree or even a PhD guarantees career stability, nor whether a decade of professional experience offers a stronger buffer.
#
# This project specifically investigates whether a PhD provides a statistically significant reduction in AI-driven automation probability when compared to 10 years of professional experience. It also evaluates whether this potential shielding effect varies across technical and service sectors. By structuring the analysis around automation probability and AI exposure indices, we move beyond general discussion and instead test whether formal education or accumulated experience serves as a more reliable predictor of job security.
#
# The theoretical foundation for this analysis comes from the task-based framework developed by Daron Acemoglu and Pascual Restrepo. Their framework argues that the impact of automation depends on the specific tasks within a job rather than the job title itself. Automation has a comparative advantage in tasks where machines can process information more efficiently, which explains why certain cognitive tasks are now highly exposed to AI. At the same time, technological change introduces new, complex tasks that favor non-routine cognitive skills, potentially creating a shielding effect for highly trained individuals. However, if AI primarily automates routine cognitive tasks that are heavily represented in technical professions, then advanced degrees may not provide the protection traditionally assumed. In service sectors, experience may matter more because these roles depend on social intelligence, tacit knowledge, and situational awareness, areas where AI remains comparatively limited.
#
# Empirical evidence reflects this tension. Tyna Eloundou et al. (2023) estimate that roughly 80 percent of the U.S. workforce could see at least 10 percent of their tasks affected by large language models, with higher exposure among workers holding advanced degrees due to the automaticity of writing and programming tasks. This challenges the assumption that more formal education linearly reduces risk. Conversely, research by Erik Brynjolfsson, Danielle Li, and Lindsey Raymond (2023) highlights complementarity effects, showing that AI can significantly boost productivity and act as a collaborator for experienced professionals rather than a substitute. The OECD’s 2023 Employment Outlook similarly identifies sectoral divergence, where AI substitutes for routine technical tasks but struggles to replace high-touch service work.
#
# Although projections about 2030 remain inherently uncertain, this project moves beyond speculation by applying task-based modeling with O*NET data and Kaggle’s AI Impact on Jobs 2030 dataset to statistically test whether a PhD or ten years of experience provides a stronger buffer against automation risk, and whether that buffering effect depends on sector.
#
# ### References
#
# Acemoglu, D., & Restrepo, P. (2019). "Automation and New Tasks: How Technology Displaces and Reinstates Labor." Journal of Economic Perspectives, 33(2), 3-30.
#
# Eloundou, T., Manning, S., Mishkin, P., & Rock, D. (2023). "GPTs are GPTs: An Early Look at the Labor Market Impact Potential of Large Language Models." arXiv preprint.
#
# Brynjolfsson, E., Li, D., & Raymond, L. R. (2023). "Generative AI at Work." National Bureau of Economic Research.
#
# OECD (2023). "OECD Employment Outlook 2023: Artificial Intelligence and the Labour Market." OECD Publishing.

# %% [markdown]
# ## Hypothesis
#
# We hypothesize that a PhD will provide a greater reduction in automation risk than 10 years of professional experience within technical sectors. However, we expect the opposite pattern in service sectors, where accumulated experience will be more protective than formal education.
#
# This hypothesis is grounded in the assumption that technical sectors reward specialized, high-level theoretical knowledge that may complement AI systems, while service sectors depend more heavily on practical judgment, tacit knowledge, and interpersonal skills that develop through experience and remain more difficult for AI to replicate. Therefore, we expect a sector-dependent shielding effect in which the relative value of education versus experience varies systematically across occupational contexts.

# %% [markdown]
# ## Data
#
# ### Data Overview
#
# #### Dataset #1
#
# - **Dataset Name:** AI Impact on Jobs 2030
# - **Link to the dataset:** https://www.kaggle.com/datasets/khushikyad001/ai-impact-on-jobs-2030
# - **Number of observations:** 3000
# - **Number of variables:** 18
#
# **Description of the variables most relevant to this project:**
#
# **Education_Level**
# Categorical variable showing the highest formal education required for the role. This represents the formal credential side of the model. I isolate the PhD category and compare its automation risk to other education levels to test whether the degree provides a measurable shielding effect.
#
# **Years_Experience**
# Numerical variable representing the average years of experience tied to the job. This represents the practical experience side of the model. I use it to group higher-experience roles and compare them directly to PhD-level roles.
#
# **Automation_Probability_2030**
# Continuous variable between 0 and 1 estimating the likelihood of automation by 2030. This is the primary dependent variable. All statistical comparisons center on this measure of risk.
#
# **Job_Title**
# Specific occupation name. Since the dataset does not include an explicit sector variable, I use job titles to manually classify occupations into technical and service sectors for moderation analysis.
#
# **AI_Exposure_Index**
# Score measuring how integrated AI is into daily job tasks. High exposure does not automatically imply high automation risk. This variable helps distinguish augmentation from replacement.
#
# **Skill_1, Skill_2, …, Skill_10**
# Numerical skill scores representing underlying capability profiles. These act as control variables, allowing analysis of whether protection comes from the degree itself or from the associated skill composition.
#
# **Risk_Category**
# Categorical label (Low, Medium, High) derived from automation probability. This is useful for validating internal consistency of the dataset.
#
# **Shortcomings of the Dataset:**
#
# - The data is synthetic, meaning any observed shielding effect may reflect built-in modeling assumptions rather than real labor market outcomes.
# - Skills are labeled generically, limiting the ability to identify which specific human capabilities drive protection from automation.
# - There is no predefined sector variable. Technical versus service classifications must be created manually, introducing subjectivity into the moderation analysis.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=101MMfKj7QZaQ8mJ6-rV7Id_y6RT1rALg', 'filename':'AI_Impact_on_Jobs_2030.csv'},
    { 'url': 'https://drive.google.com/uc?export=download&id=1lkkcHYmah0_RW8uJpRKFgK9DRdIWV056', 'filename':'OECD_AI_and_Employment_Surveys.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### Dataset #1
#
# Instructions: REPLACE the contents of this cell and the one below with your work, including any updates to recover points lost in your data checkpoint feedback

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np
import os


raw_data_path = "data/00-raw/AI_Impact_on_Jobs_2030.csv"
df = pd.read_csv(raw_data_path)
df_clean = df.dropna(how='any').copy()
df_clean.columns = [col.lower() for col in df_clean.columns]
print("Data loaded successfully!\n")


rows, cols = df.shape
print(f"Dataset Size: {rows} rows and {cols} columns.\n")


print("First 3 rows to demonstrate tidiness:")
print(df.head(3))
print("\nObservation: The dataset is already tidy. Each job listing is a unique observation (row), "
      "and every attribute like Salary, Experience, and Probability represents a distinct variable (column). "
      "No melting or pivoting is needed.\n")


missing_data = df.isnull().sum()
total_missing = missing_data.sum()

print("Missing Data per Column:")
print(missing_data[missing_data > 0] if total_missing > 0 else "No missing values in any column.\n")


numeric_cols = df.select_dtypes(include=[np.number]).columns
z_scores = np.abs((df[numeric_cols] - df[numeric_cols].mean()) / df[numeric_cols].std())

outliers_count = (z_scores > 3).sum()
print("Number of extreme outliers (Z-score > 3) per column:")
print(outliers_count)


suspicious_entries = df[
    (df['Average_Salary'] < 0) | 
    (df['Years_Experience'] < 0) | 
    (df['Automation_Probability_2030'] > 1) | 
    (df['Automation_Probability_2030'] < 0)
]
print(f"\nNumber of suspicious/impossible entries found: {len(suspicious_entries)}\n")


processed_path = 'data/02-processed/AI_Impact_on_Jobs_2030_cleaned.csv'
df_clean.to_csv(processed_path, index=False)
print(f"Saved final wrangled data to: {processed_path}\n")


print("==========================================")
print("Summary Statistics for Key Variables:")
important_vars = ['average_salary', 'years_experience', 'ai_exposure_index', 'automation_probability_2030']
print(df_clean[important_vars].describe().round(2))

print("\nDistribution of Job Risk Categories:")
print(df_clean['risk_category'].value_counts())
print("==========================================")

# %% [markdown]
# ### Dataset #2
#  as above, add any more copies of this that you need to given how many datasets you have

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np
import os

raw_data_path = "data/00-raw/OECD_AI_and_Employment_Surveys.csv"

df = pd.read_csv(raw_data_path)
print("Data loaded successfully!\n")


rows, cols = df.shape
print(f"Dataset Size: {rows} rows and {cols} columns.\n")


print("First 3 rows to demonstrate tidiness:")
print(df.head(3))
print("\nObservation: The dataset is already tidy. Each row represents a specific observation "
      "for a given country/territory in a specific year, with a single value for the "
      "'publications' measure. Variables like 'Country/territory', 'year', and 'publications' "
      "each have their own distinct columns.\n")


missing_data = df.isnull().sum()
total_missing = missing_data.sum()

print("Missing Data per Column:")
print(missing_data[missing_data > 0] if total_missing > 0 else "No missing values in any column.\n")

if total_missing == 0:
    print("There is 0 missing data across the entire dataset, "
          "there are no systematic relationships or 'Missing At Random'.\n")


numeric_cols = df.select_dtypes(include=[np.number]).columns
z_scores = np.abs((df[numeric_cols] - df[numeric_cols].mean()) / df[numeric_cols].std())

outliers_mask = (z_scores > 3)
outliers_count = outliers_mask.sum()
print("Number of extreme outliers (Z-score > 3) per numeric column:")
print(outliers_count)

if outliers_count['publications'] > 0:
    print("\nFlagged Outliers in Publications (Z-Score > 3):")
    outlier_rows = df[outliers_mask['publications']]
    print(outlier_rows[['Country/territory_label', 'year', 'publications']])
    

suspicious_entries = df[
    (df['publications'] < 0) | 
    (df['year'] > 2026) 
]
print(f"\nNumber of suspicious/impossible entries found: {len(suspicious_entries)}\n")


df_clean = df.dropna(how='any').copy()

cols_to_drop = [col for col in df_clean.columns if df_clean[col].nunique() == 1]
if cols_to_drop:
    df_clean = df_clean.drop(columns=cols_to_drop)
    print(f"Dropped redundant columns with only one unique value: {cols_to_drop}")

df_clean.columns = df_clean.columns.str.lower().str.replace('/', '_').str.replace(' ', '_')


processed_path = 'data/02-processed/OECD_AI_and_Employment_Surveys_cleaned.csv'
df_clean.to_csv(processed_path, index=False)
print(f"Saved final wrangled data to: {processed_path}\n")


print("==========================================")
print("Summary Statistics for Numeric Variables:")
print(df_clean[['publications', 'year']].describe().round(2))

print("\nNumber of records per Country/Territory Label:")
print(df_clean['country_territory_label'].value_counts())
print("==========================================")

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# In this section we take a look at the cleaned `AI_Impact_on_Jobs_2030` dataset to try and make sense of the underlying distributions of our key variables, identify any hidden outliers, and begin mapping the relationships between education, experience, and automation risk.
#
# Since our hypothesis is mainly focused on the job security power of a PhD versus 10+ years of experience, we will focus our visualizations on how `automation_probability_2030` interacts with `education_level` and `years_experience`.
#
# First, we will load our wrangled dataset and set up our visualization libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", palette="muted")

df_jobs = pd.read_csv('data/02-processed/AI_Impact_on_Jobs_2030_cleaned.csv')

print(f"Data loaded successfully. Shape: {df_jobs.shape}")

# %% [markdown]
# #### 1. Distributions of Key Variables
# To start, we need to understand the shape of our primary dependent variable (`automation_probability_2030`) and our key independent variables.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.histplot(df_jobs['automation_probability_2030'], bins=20, kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Distribution of Automation Probability (2030)')
axes[0].set_xlabel('Automation Probability')
axes[0].set_ylabel('Frequency')

sns.histplot(df_jobs['years_experience'], bins=15, kde=True, ax=axes[1], color='lightgreen')
axes[1].set_title('Distribution of Years of Experience')
axes[1].set_xlabel('Years of Experience')

sns.countplot(data=df_jobs, x='education_level', hue='education_level', 
              order=['High School', "Bachelor's", "Master's", 'PhD'], 
              ax=axes[2], palette='Set2', legend=False)
axes[2].set_title('Count of Jobs by Education Level')
axes[2].set_xlabel('Education Level')
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation of Distributions:**
# * **Automation Probability:** The distribution is relatively uniform, meaning the synthetic dataset features a balanced mix of low, medium, and high-risk jobs. This is ideal for our regression models, as we won't suffer from a heavily skewed target variable.
# * **Years of Experience:** Experience is also uniformly distributed from 0 to roughly 30 years. This guarantees we have a sufficient sample size of jobs with "10+ years of experience" to test our hypothesis against the PhD category.
# * **Education Level:** The dataset contains an even spread across the four education tiers. We have an adequate baseline of PhD-level occupations to establish statistical significance later.

# %% [markdown]
# #### 2. Outlier Detection
# While our Checkpoint 1 Z-score analysis confirmed there were no extreme statistical outliers (> 3 std devs), visualizing the spread of continuous variables like Salary and Experience is still best practice.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

sns.boxplot(y=df_jobs['average_salary'], ax=axes[0], color='salmon')
axes[0].set_title('Boxplot of Average Salary')
axes[0].set_ylabel('Average Salary (USD)')

sns.boxplot(y=df_jobs['years_experience'], ax=axes[1], color='gold')
axes[1].set_title('Boxplot of Years of Experience')
axes[1].set_ylabel('Years of Experience')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation of Outliers:**
# The boxplots confirm our earlier statistical checks: there are no points resting outside the interquartile range (IQR) whiskers for either salary or experience. We do not need to apply transformations to handle heavy tails.

# %% [markdown]
# #### 3. Relationships Between Variables
# Here we test the core relationships driving our hypothesis: How does education compare to experience when predicting automation risk?

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.boxplot(x='education_level', y='automation_probability_2030', hue='education_level',
            order=['High School', "Bachelor's", "Master's", 'PhD'], 
            data=df_jobs, ax=axes[0], palette='pastel', legend=False)
axes[0].set_title('Automation Risk by Education Level')
axes[0].set_xlabel('Education Level')
axes[0].set_ylabel('Automation Probability')

sns.scatterplot(x='years_experience', y='automation_probability_2030', 
                data=df_jobs, alpha=0.3, ax=axes[1], color='purple')
sns.regplot(x='years_experience', y='automation_probability_2030', 
            data=df_jobs, scatter=False, ax=axes[1], color='black', line_kws={"linestyle": "--"})

axes[1].set_title('Automation Risk vs. Years of Experience')
axes[1].set_xlabel('Years of Experience')
axes[1].set_ylabel('Automation Probability')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation of Relationships:**
# * **Education Shielding:** Looking at the boxplot, the median automation probability is noticeably lower for roles requiring a PhD compared to High School or Bachelor's degrees. This provides early visual support for the first half of our hypothesis: advanced formal education appears to correlate with a drop in automation risk.
# * **Experience Shielding:** Interestingly, the scatter plot and trendline show a practically flat relationship between years of experience and automation probability. Across the entire dataset, simply having 10+ years of experience does not yield an obvious, immediate drop in risk.
# * **Next Steps:** Because experience doesn't show a strong universal correlation, this strongly supports our need to split the data by our moderating variables (Technical vs. Service sectors). It is highly likely that experience reduces risk in *some* sectors but not others, effectively canceling out the trendline when viewed globally.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.histplot(df_jobs['automation_probability_2030'], bins=20, kde=True, ax=axes[0], color='skyblue')
axes[0].set_title('Distribution of Automation Probability (2030)')
axes[0].set_xlabel('Automation Probability')
axes[0].set_ylabel('Frequency')

sns.histplot(df_jobs['years_experience'], bins=15, kde=True, ax=axes[1], color='lightgreen')
axes[1].set_title('Distribution of Years of Experience')
axes[1].set_xlabel('Years of Experience')

sns.countplot(data=df_jobs, x='education_level', hue='education_level', 
              order=['High School', "Bachelor's", "Master's", 'PhD'], 
              ax=axes[2], palette='Set2', legend=False)
axes[2].set_title('Count of Jobs by Education Level')
axes[2].set_xlabel('Education Level')
axes[2].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4. Feature Correlation Matrix
# Finally, we will look at the global correlations between all of our numeric variables to spot potential multicollinearity issues before building our regression models.

# %%
plt.figure(figsize=(10, 8))

num_cols = ['average_salary', 'years_experience', 'ai_exposure_index', 
            'tech_growth_factor', 'automation_probability_2030']

corr_matrix = df_jobs[num_cols].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of Numeric Variables')
plt.show()

# %% [markdown]
# **Interpretation of Correlation Heatmap:**
# * The correlation between variables is incredibly close to `0.00` across the board. `years_experience`, `average_salary`, and `automation_probability` show virtually no linear correlation with one another.
# * **The Synthetic Data Caveat:** This lack of correlation is highly unusual for real-world labor data (where experience and salary usually correlate strongly). This confirms our ethical concern from Checkpoint 1: the synthetic generation of this dataset likely assigned these continuous variables independently.
# * **Modeling Implications:** Because our independent continuous variables aren't heavily correlated, we don't have to worry about multicollinearity in our multiple linear regression. However, it also means our models will likely rely heavily on the categorical variables (Education and our upcoming manual Technical/Service Sector split) to find significance.

# %% [markdown]
# #### 5. Critical Finding: The Limitations of Synthetic Data
# During our EDA, we uncovered a significant structural issue with our primary dataset (`AI_Impact_on_Jobs_2030`). While the Kaggle page notes that the data is synthetic, our visualizations reveal that it is functionally random noise.
#
# The evidence for this includes:
# 1. **Perfectly Uniform Distributions:** The distributions for `years_experience` and `automation_probability_2030` are suspiciously flat and uniform, lacking the natural right-skew or bell curves typical of human labor data.
# 2. **Zero Categorical Variance:** The boxplots measuring Automation Risk by Education Level are mathematically identical across all four tiers. The synthetic generator did not encode any relationship between education and risk.
# 3. **Absence of Multicollinearity:** The correlation matrix shows a uniform `0.00` to `0.03` correlation across all numeric variables. In real-world labor economics, variables like `average_salary` and `years_experience` are heavily correlated. Here, they are entirely independent.
#
# **Conclusion for our Hypothesis:** Because the variables were generated randomly and independently, there is no underlying mathematical signal to capture. Running a Multiple Linear Regression on this dataset will inherently yield insignificant p-values, making it impossible to genuinely test our hypothesis regarding the shielding effects of a PhD versus experience.
#
# **Next Steps for the Project:**
# To conduct a valid statistical analysis, we must decide whether to pivot our research question to analyze the flaws of AI-generated synthetic datasets, or source a new, real-world labor dataset (such as from O*NET or the Bureau of Labor Statistics) to evaluate our original hypothesis.

# %% [markdown]
# ## Ethics
#
# ### Data Collection and Bias
# Our team has carefully evaluated the potential for collection bias within the Kaggle "AI Impact on Jobs 2030" dataset. Because the risk scores are based on future projections, they are subject to the subjective judgment of the researchers and experts who originally labeled the data. This creates a risk of bias, where high-level formal education (like a Master's or PhD) may be viewed as more irreplaceable simply because the experts themselves possess those credentials. We will mitigate this by comparing these projections against historical trends of automation to see if the protective nature of education remains consistent across different data models.
#
# ### Proxy Discrimination and Social Impact
# A central ethical concern of this study is the risk of proxy discrimination. Formal education levels and years of professional experience are often highly correlated with socioeconomic status, race, and geographic access to resources. By investigating whether a PhD provides a "statistically significant reduction" in automation risk, we acknowledge that we are studying a variable that is not accessible to everyone. We must be careful not to frame our results in a way that suggests lower-educated workers are at fault for their automation risk, but rather highlight how systemic barriers to education may create a disadvantage in the future labor market.
#
# ### Honest Representation and Limitations
# To ensure the honest representation of our findings, our analysis will include measures of variance and uncertainty rather than just average risk scores. AI development is notoriously non-linear, as seen with the sudden emergence of Large Language Models, and a "2030 projection" is a snapshot of current expectations that could change rapidly. We will communicate these limitations clearly to prevent our model from being used as a definitive tool for high-stakes career or policy decisions. Our goal is to provide a reproducible and auditable analysis that contributes to the discussion on workforce transition without overstating the predictive power of our results.
#
# ### Data Retention and Auditability
# In accordance with the project's lifecycle, we have established a data retention plan where all processed datasets and intermediate analysis files will be deleted upon the final grading of the project. To maintain auditability, we will document our entire methodology, from data cleaning to the final statistical tests, within our Jupyter Notebook. This ensures that our process is transparent and that any biases introduced during the wrangling phase can be identified and corrected by others in the research community.
#
# ### Biases / Privacy / Terms of Use
# **Are there any biases/privacy/terms of use issues with the data you proposed?**
# The datasets we are using are publicly available and anonymized, so there are no direct privacy concerns. There is no personally identifiable information. We will follow all citation rules and terms of use for both the Kaggle and OECD data. The real issue to worry about is projection bias. The Kaggle dataset is based on expert-labeled automation risk scores, not real observed outcomes. That means those scores reflect assumptions about which jobs are replaceable.
#
# **Are there potential biases in your dataset(s), in terms of who it composes and how it was collected?**
# Yes. Large labor datasets usually focus on formal occupations. Gig workers and people in unconventional paths are probably not fully represented. Education and experience are also highly correlated with socioeconomic status and access to opportunity. The differences between the datasets are probably indicative of systemic inequality instead of just pure skill differences.
#
# **How will you detect these specific biases before, during, and after analysis?**
# Before running models, we will check how education levels, sectors, and industries are distributed to see if certain groups are overrepresented or underrepresented. We will compare this to external labor statistics. During analysis, we will run subgroup regressions and test alternative model specifications to see if results are driven by specific groups. After analysis, we will report uncertainty measures and run sensitivity checks. If conclusions change under different assumptions, we will state that clearly.
#
# **Are there any other issues related to your topic, data, and/or analyses that are potentially problematic?**
# Yes. Automation probability is a projection, not a guarantee of job loss. There is a risk that people interpret our findings as definitive career advice. There is also a risk of reinforcing narratives that lower education equals higher replaceability, which oversimplifies structural labor market dynamics.
#
# **How will you handle the issues you identified?**
# We will clearly state that our results are probabilistic and based on projections. We will avoid deterministic language. Furthermore, we will frame our findings around structural trends rather than individual shortcomings. All data cleaning, modeling decisions, and limitations will be documented, so the analysis is transparent and reproducible.

# %% [markdown]
# ## Team Expectations
#
# - Communication will take place through Discord and iMessage.
# - The general expectation for a response is within 6 hours.
# - For messages sent between 9 AM and 9 PM, a response is expected within 12 hours.
# - The group will meet once a week through a Discord call.
# - There are no specific expectations around tone, as long as everyone is respectful.
# - All major decisions will be made by a majority vote of the present group members.
# - For general tasks, everyone is expected to do a bit of everything.
# - Each team member will also be responsible for at least one major task, such as data cleaning, modeling, visualization, writing, or validation.
# - Members must update the group whenever they make a change to a shared file.
# - Group members should help anyone who is struggling with a particular task.
# - All major decisions must be documented on GitHub to maintain a clear record.
# - We understand that everyone has responsibilities outside this class, and we want to respect that. If someone cannot meet a deadline, they need to communicate that as early as possible. They are also responsible for delegating their task and providing a clear outline of what has been done and what still needs to be completed, since the rest of the group will be stepping in.

# %% [markdown]
# ## Project Timeline Proposal
#
# We’ve been on track thus far. This timeline that we created for the project proposal has been very productive and helpful. As long as we stay on this track, we’ll accomplish our goals!
#
# | Date      | Time | Tasks |
# |-----------|------|-------|
# | 3/8/26    | 8PM  | Each member writes a summary of the findings for their assigned variables (Education, Experience, or Sector). Discuss/edit Analysis; Complete project check-in |
# | 3/15/26   | 8PM  | Combine the Introduction, Methodology, Ethics, and Analysis into one master document. Discuss/edit full project |
# | 3/20/26   | 8PM  | Finish project. Turn in Final Project & Group Project Surveys |
